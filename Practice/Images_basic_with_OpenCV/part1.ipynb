# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

# %%
img = cv2.imread('D:\ANSON\OpenCV\Computer-Vision-with-Python\DATA\\00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
gray_img = cv2.imread('D:\ANSON\OpenCV\Computer-Vision-with-Python\DATA\\00-puppy.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(gray_img)

# %%
gray_img.shape
# Out:
# (1300, 1950)

# %%
plt.imshow(gray_img, cmap='gray')

# %%
w_ratio = 0.8
h_ratio = 0.2

# %%
new_img = cv2.resize(fix_img, (0,0),fix_img, w_ratio, h_ratio)
plt.imshow(new_img)

# %%
new_img_1 = cv2.flip(fix_img, -1)
plt.imshow(new_img_1)

# %%
cv2.imwrite('flip.jpg', new_img_1)
# Out:
# True

# %%
fig = plt.figure(figsize=(5,5))
ax1 = fig.add_subplot(111)
ax2 = fig.add_subplot(121)
ax3 = fig.add_subplot(131)
ax1.imshow(new_img)
ax2.imshow(fix_img)
ax3.imshow(new_img_1)
